# %%
# CNN = {Accuracy: 0.5013089005235603
# Precision: 0.5012285012285013
# Recall: 0.5340314136125655
# F1-score: 0.5171102661596958}

# resnet = {Accuracy: 0.5
# Precision: 0.5
# Recall: 0.9947643979057592
# F1-score: 0.6654991243432574

# }

# vgg = {Accuracy: 0.4908376963350785
# Precision: 0.49081364829396323
# Recall: 0.4895287958115183
# F1-score: 0.49017038007863695}


import matplotlib.pyplot as plt
import numpy as np

# Data
models = ['CNN', 'ResNet', 'VGG']
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score']

# Values for each model
cnn = [0.5013089005235603, 0.5012285012285013, 0.5340314136125655, 0.5171102661596958]
resnet = [0.5, 0.5, 0.9947643979057592, 0.6654991243432574]
vgg = [0.4908376963350785, 0.49081364829396323, 0.4895287958115183, 0.49017038007863695]

# Create an array for the x positions of the bars
x = np.arange(len(metrics))

# Width of the bars
width = 0.2

# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot bars for each model
rects1 = ax.bar(x - width, cnn, width, label='CNN')
rects2 = ax.bar(x, resnet, width, label='ResNet')
rects3 = ax.bar(x + width, vgg, width, label='VGG')

# Add labels, title, and custom x-axis tick labels
ax.set_xlabel('Metrics')
ax.set_ylabel('Scores')
ax.set_title('Comparison of Models (CNN, ResNet, VGG)')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Correct Prediction/Output - CNN, VGG

# %%
#CNN much faster, less time consuming #VGG high time consuming
